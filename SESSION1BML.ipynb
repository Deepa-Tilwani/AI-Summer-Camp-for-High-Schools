# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepa-Tilwani/AI-Summer-Camp-for-High-Schools/blob/main/SESSION1BML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # All the libraries we need for linear SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %% [markdown]
# These lines import the necessary libraries: NumPy for numerical computations, Matplotlib for plotting, and scikit-learn's SVM module.

# %%
from sklearn.datasets import load_breast_cancer
dataCancer = load_breast_cancer()

# %% [markdown]
# These lines import the breast cancer dataset from scikit-learn and assign it to the variable dataCancer.

# %%
data = dataCancer.data[:, 0:2]
target = dataCancer.target

# %% [markdown]
# Here, we extract two features (columns 0 and 1) from the breast cancer dataset and assign them to the variable data. The corresponding classification labels are assigned to the variable target.

# %%
model = svm.SVC(kernel='linear', C=10000)
model.fit(data, target)
# Out:
# SVC(C=10000, kernel='linear')

# %% [markdown]
# This code creates a linear SVM model with a linear kernel and a regularization parameter C set to 10000. It then fits the model to the data and target.

# %%
plt.scatter(data[:, 0], data[:, 1], c=target, s=30, cmap=plt.cm.prism)

# %%
# plots the points
plt.scatter(data[:, 0], data[:, 1], c=target, s=30, cmap=plt.cm.prism)

# Creates the axis bounds for the grid
axis = plt.gca()
x_limit = axis.get_xlim()
y_limit = axis.get_ylim()

# Creates a grid to evaluate model
x = np.linspace(x_limit[0], x_limit[1], 50)
y = np.linspace(y_limit[0], y_limit[1], 50)
X, Y = np.meshgrid(x, y)
xy = np.c_[X.ravel(), Y.ravel()]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import load_breast_cancer

# Load breast cancer dataset
data_cancer = load_breast_cancer()
data = data_cancer.data[:, :2]  # Select first two features
target = data_cancer.target

# Create and train the linear SVM model
model = svm.SVC(kernel='linear', C=10000)
model.fit(data, target)

# Create a scatter plot of the data points
plt.scatter(data[:, 0], data[:, 1], c=target, s=30, cmap='viridis')

# Generate a grid of points to evaluate the decision function
x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))
grid_data = np.c_[xx.ravel(), yy.ravel()]

# Compute the decision function for the grid points
decision_values = model.decision_function(grid_data)
decision_values = decision_values.reshape(xx.shape)

# Plot the decision boundary and margins
plt.contour(xx, yy, decision_values, levels=[0], colors='black')

# Highlight the support vectors
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
            s=100, linewidth=1, facecolors='none', edgecolors='black')

# Set plot title and axis labels
plt.title("Breast Cancer Classification with Linear SVM")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

# Show the plot
plt.show()
